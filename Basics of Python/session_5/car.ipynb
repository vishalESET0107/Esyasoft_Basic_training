# %%
import pandas as pd

import numpy as np

df = pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (11914, 16)

# %%
print(df.loc[1])
# Out:
# Make                              BMW
# Model                        1 Series
# Year                             2011
# hp                              300.0
# cylinders                         6.0
# Transmission Type              MANUAL
# drivenwheels         rear wheel drive
# Number of Doors                   2.0
# Vehicle Style             Convertible
# highway MPG                        28
# city mpg                           19
# Popularity                       3916
# MSRP                            40650
# Name: 1, dtype: object

# %%
df.drop_duplicates()
# Out:
#           Make       Model  Year     hp  cylinders Transmission Type  \
# 0          BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1          BMW    1 Series  2011  300.0        6.0            MANUAL
# 2          BMW    1 Series  2011  300.0        6.0            MANUAL
# 3          BMW    1 Series  2011  230.0        6.0            MANUAL
# 4          BMW    1 Series  2011  230.0        6.0            MANUAL
# ...        ...         ...   ...    ...        ...               ...
# 11909    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0         AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0         AUTOMATIC
#
#             drivenwheels  Number of Doors  Vehicle Style  highway MPG  \
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
duplicate = df[df.duplicated()]
print(duplicate.shape)
# Out:
# (715, 16)

# %%
df = df.drop([ 'Vehicle Size','Engine Fuel Type' ,'Market Category' ],  axis = 1)

# %%
print(df['Year'])
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 11909    2012
# 11910    2012
# 11911    2012
# 11912    2013
# 11913    2006
# Name: Year, Length: 11815, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11815 entries, 0 to 11913
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11815 non-null  object
#  1   Model              11815 non-null  object
#  2   Year               11815 non-null  int64
#  3   hp                 11815 non-null  float64
#  4   cylinders          11815 non-null  float64
#  5   Transmission Type  11815 non-null  object
#  6   drivenwheels       11815 non-null  object
#  7   Number of Doors    11815 non-null  float64
#  8   Vehicle Style      11815 non-null  object
#  9   highway MPG        11815 non-null  int64
#  10  city mpg           11815 non-null  int64
#  11  Popularity         11815 non-null  int64
#  12  MSRP               11815 non-null  int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 1.3+ MB

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.shape
# Out:
# (11914, 12)

# %%
df =df.rename(columns= {'Engine HP' : 'hp' , 'Driven_Wheels' : 'drivenwheels' , 'Engine Cylinders' : 'cylinders'})

# %%
df
# Out:
#           Make       Model  Year     hp  cylinders Transmission Type  \
# 0          BMW  1 Series M  2011  335.0        6.0            MANUAL
# 1          BMW    1 Series  2011  300.0        6.0            MANUAL
# 2          BMW    1 Series  2011  300.0        6.0            MANUAL
# 3          BMW    1 Series  2011  230.0        6.0            MANUAL
# 4          BMW    1 Series  2011  230.0        6.0            MANUAL
# ...        ...         ...   ...    ...        ...               ...
# 11909    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11910    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11911    Acura         ZDX  2012  300.0        6.0         AUTOMATIC
# 11912    Acura         ZDX  2013  300.0        6.0         AUTOMATIC
# 11913  Lincoln      Zephyr  2006  221.0        6.0         AUTOMATIC
#
#             drivenwheels  Vehicle Style  highway MPG  city mpg  Popularity  \
# ...

# %%
duplicate = df[df.duplicated()]
print(duplicate.shape)
# Out:
# (802, 13)

# %%
df.shape
# Out:
# (803, 12)

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# hp                   11845
# cylinders            11884
# Transmission Type    11914
# drivenwheels         11914
# Number of Doors      11908
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.isnull()
# Out:
#         Make  Model   Year     hp  cylinders  Transmission Type  drivenwheels  \
# 0      False  False  False  False      False              False         False
# 1      False  False  False  False      False              False         False
# 2      False  False  False  False      False              False         False
# 3      False  False  False  False      False              False         False
# 4      False  False  False  False      False              False         False
# ...      ...    ...    ...    ...        ...                ...           ...
# 11909  False  False  False  False      False              False         False
# 11910  False  False  False  False      False              False         False
# 11911  False  False  False  False      False              False         False
# 11912  False  False  False  False      False              False         False
# 11913  False  False  False  False      False              False         False
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Make                  0
# Model                 0
# Year                  0
# hp                   69
# cylinders            30
# Transmission Type     0
# drivenwheels          0
# Number of Doors       6
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
df = df.dropna()

# %%
print(df.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# hp                   0
# cylinders            0
# Transmission Type    0
# drivenwheels         0
# Number of Doors      0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.shape
# Out:
# (11815, 13)

# %%
numeric = df.select_dtypes(include=['number'])


q1 = numeric.df.quantile(0.25)
q3 = numeric.df.quantile(0.75)

IQR = q3-q1

print(IQR)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22308\4068766302.py in ?()
#       1 numeric = df.select_dtypes(include=['number'])
#       2
#       3
# ----> 4 q1 = numeric.df.quantile(0.25)
#       5 q3 = numeric.df.quantile(0.75)
#       6
#       7 IQR = q3-q1
#
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
numeric = df.select_dtypes(include=['number'])

# Calculate quartiles
q1 = numeric.quantile(0.25)
q3 = numeric.quantile(0.75)

# Calculate IQR
IQR = q3 - q1

print(IQR)
# Out:
# Year                   9.0
# hp                   130.0
# cylinders              2.0
# Number of Doors        2.0
# highway MPG            8.0
# city mpg               6.0
# Popularity          1460.0
# MSRP               21210.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x=df['hp'])
# Out:
# <Axes: xlabel='hp'>

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize = (10,5))
plt.title('number of cars by make')
plt.ylabel('number of cars')
plt.xlabel('make')
# Out:
# Text(0.5, 0, 'make')

# %% [markdown]
# #heatmaps

# %%
#bivariate

plt.figure(figsize=(10,5))

numeric = df.select_dtypes(include=['number'])
c=numeric.corr()
sns.heatmap(c,cmap="BrBG" , annot = True)
c
# Out:
#                      Year        hp  cylinders  Number of Doors  highway MPG  \
# Year             1.000000  0.352980  -0.034494         0.262265     0.280210
# hp               0.352980  1.000000   0.779740        -0.102070    -0.414183
# cylinders       -0.034494  0.779740   1.000000        -0.137584    -0.620316
# Number of Doors  0.262265 -0.102070  -0.137584         1.000000     0.120925
# highway MPG      0.280210 -0.414183  -0.620316         0.120925     1.000000
# city mpg         0.232439 -0.465903  -0.637879         0.136574     0.847022
# Popularity       0.073709  0.036680   0.045001        -0.049978    -0.029203
# MSRP             0.227381  0.661833   0.543971        -0.127367    -0.198942
#
#                  city mpg  Popularity      MSRP
# Year             0.232439    0.073709  0.227381
# hp              -0.465903    0.036680  0.661833
# cylinders       -0.637879    0.045001  0.543971
# Number of Doors  0.136574   -0.049978 -0.127367
# ...
